# %%
import bs4
import requests
url = 'https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation='
def find_jobs(url):
    html_text = requests.get(url)
    html_content = html_text.text
    soup = bs4.BeautifulSoup(html_content, 'lxml')
    jobs = soup.find_all('li', class_='clearfix job-bx wht-shd-bx')
    job_lists = []
    for job in jobs:
        company_name = job.find('h3', class_='joblist-comp-name').text.strip()
        exp = job.find('li').text.replace('card_travel','')
        job_loc = job.find('span').text
        job_desc = job.find('ul', class_='list-job-dtl clearfix').li.text.split('\n')[2]
        key_skills = job.find('span', class_='srp-skills').text.strip()
        post_date = job.find('span', class_='sim-posted').text.strip()
        job_desc_link = job.header.h2.a['href']
        
        job_dict = {
            'Company Name':company_name,
            'Experience':exp,
            'Job Location':job_loc,
            'Job Description':job_desc,
            'Key Skills':key_skills,
            'Post Date':post_date,
            'Job Link':job_desc_link
        }
        job_lists.append(job_dict)
    return job_lists

# %%
find_jobs(url)[0]
# Out:
# {'Company Name': 'Pure Tech Codex Private Limited',
#  'Experience': '2 - 3 yrs',
#  'Job Location': 'Pune',
#  'Job Description': 'Job Description: 2 to 3 Years experience in Python.Expert in Python ,  with knowledge of at least one Python web framework  Flask ,  Django etc.Expert in server programming.Go... More Details',
#  'Key Skills': 'rest  ,  python  ,  database  ,  django  ,  debugging  ,  mongodb',
#  'Post Date': 'Posted few days ago',
#  'Job Link': 'https://www.timesjobs.com/job-detail/python-pure-tech-codex-private-limited-pune-2-to-3-yrs-jobid-OHwfF0d6EhNzpSvf__PLUS__uAgZw==&source=srp'}

# %%
import pandas as pd
df = pd.DataFrame(find_jobs(url))
df
# Out:
#                                          Company Name Experience  \
# 0                     Pure Tech Codex Private Limited  2 - 3 yrs
# 1               Surya Informatics Solutions Pvt. Ltd.  0 - 3 yrs
# 2                                    Gemini Solutions  4 - 7 yrs
# 3     Eternal HR Services Pvt Ltd\r\n     (More Jobs)  3 - 8 yrs
# 4   Software Development Center - Lenze Mechatroni...  4 - 6 yrs
# 5                             Ivan Infotech Pvt. Ltd.  2 - 5 yrs
# 6                                        DBS Bank Ltd  0 - 3 yrs
# 7                                   CONNECTING 2 WORK  0 - 3 yrs
# 8                                  TandA HR Solutions  4 - 6 yrs
# 9                                      dbs asia hub 2  0 - 3 yrs
# 10                                 Datagrid Solutions  2 - 3 yrs
# 11                         east india securities ltd.  2 - 5 yrs
# 12                                 TandA HR Solutions  0 - 3 yrs
# 13                                        hk infosoft  2 - 3 yrs
# 14                                 TandA HR Solutions  5 - 8 yrs
# 15                               LAKSH HUMAN RESOURCE  1 - 3 yrs
# 16                    BRICKRED TECHNOLOGIES PVT. LTD.  0 - 3 yrs
# 17                    BRICKRED TECHNOLOGIES PVT. LTD.  0 - 3 yrs
# 18                    BRICKRED TECHNOLOGIES PVT. LTD.  0 - 3 yrs
# 19                                 TandA HR Solutions  2 - 5 yrs
# 20               Perfios Software Solutions Pvt. Ltd.  5 - 8 yrs
# 21                                 JobsLo Consultants  2 - 3 yrs
# 22                       brickred  ( 3pillar global )  4 - 7 yrs
# 23                                               kpmg  0 - 3 yrs
# 24                            Wing Global IT Services  2 - 5 yrs
#
#               Job Location                                    Job Description  \
# 0                     Pune  Job Description: 2 to 3 Years experience in Py...
# 1                  Chennai  POSITION: Python Developer ELIGIBILITY: FRESHE...
# 2                  Gurgaon  4  Years GurgaonB.TechRequired Skills 4   year...
# 3             (More Jobs)   Python DeveloperExp of 4 + YrsGood python prog...
# 4             (More Jobs)   Lenze Software Development Center  ( SDC ) -R ...
# 5                  Kolkata  We are looking for a Python Developer to join ...
# 6   Hyderabad/Secunderabad  Python Engineer -  (  WD32434  ) Responsibilit...
# 7       Calicut/ Kozhikode  Job Description We are looking for candidates ...
# 8     Gurgaon,  Chandigarh  Good to have working knowledge on unit testing...
# 9   Hyderabad/Secunderabad  Design and build from scratch for enterprise o...
# 10                  Mumbai  Write well designed and optimized codeContribu...
# 11                 Kolkata  job_description   2  years of experience worki...
# 12                 Gurgaon  Urgent Requirement of Python Developer profile...
# 13               Ahmedabad  Expert in Python ,  framework such as Django ,...
# 14              Chandigarh  Opening for Python Developer profile in a MNC ...
# 15                  Mumbai  Powai ,  Mumbai Python Developer Experience : ...
# 16                          Detailed Job Description:1. Proficient in pyth...
# 17                          1. Proficient in python and numerical programm...
# 18                          JD1. Proficient in python and numerical progra...
# 19              Chandigarh  Job Description: Good to have working knowledg...
# 20   Bengaluru / Bangalore  Were looking for experienced developers who ar...
# 21                  Indore  Job Description : Python DeveloperQualificatio...
# 22                          We build breakthrough software products that p...
# 23   Bengaluru / Bangalore  TEAM INFORMATIONAs part of the engineering fun...
# 24               Panchkula  Candidates should be completed Graduation at l...
#
#                                            Key Skills  \
# 0   rest  ,  python  ,  database  ,  django  ,  de...
# 1   python  ,  web technologies  ,  linux  ,  mobi...
# 2   python  ,  mobile  ,  svn  ,  nosql  ,  python...
# 3                                      Python  ,  SQL
# 4   Python Scripting  ,  Selenium WebDriver  ,  OO...
# 5          rest  ,  python  ,  security  ,  debugging
# 6   python  ,  java  ,  infrastructure  ,  softwar...
# 7              rest  ,  python  ,  django  ,  mongodb
# 8                           python  ,  git  ,  django
# 9   python  ,  java  ,  infrastructure  ,  softwar...
# 10   python  ,  database  ,  django  ,  mysql  ,  api
# 11             python  ,  hadoop  ,  machine learning
# 12                          python  ,  django  ,  sql
# 13              python  ,  django  ,    ,   framework
# 14                          python  ,  git  ,  django
# 15                 rest  ,  python  ,  django  ,  git
# 16             image processing  ,  python  ,  opencv
# 17             image processing  ,  python  ,  opencv
# 18             image processing  ,  python  ,  opencv
# 19                          python  ,  git  ,  django
# 20                          python  ,  java  ,  scala
# 21               python  ,  linux  ,  windows  ,  sql
# 22          software products  ,  Python  ,  DynamoDB
# 23  docker  ,  database  ,  software engineer  ,  ...
# 24  spring boot  ,  python  ,  java  ,  django  , ...
#
#                                            Post Date  \
# 0                                Posted few days ago
# 1                                Posted few days ago
# 2                                Posted few days ago
# 3   Work from Home \r\n\t\t    \t\nPosted 5 days ago
# 4                                  Posted 3 days ago
# 5                                Posted few days ago
# 6                                Posted few days ago
# 7                                Posted few days ago
# 8                                Posted few days ago
# 9                                Posted few days ago
# 10                               Posted few days ago
# 11                               Posted few days ago
# 12                               Posted few days ago
# 13                               Posted few days ago
# 14                               Posted few days ago
# 15                               Posted few days ago
# 16                               Posted few days ago
# 17                               Posted few days ago
# 18                               Posted few days ago
# 19                               Posted few days ago
# 20                               Posted few days ago
# 21                               Posted few days ago
# 22                               Posted few days ago
# 23                                  Posted 1 day ago
# 24                               Posted few days ago
#
#                                              Job Link
# 0   https://www.timesjobs.com/job-detail/python-pu...
# 1   https://www.timesjobs.com/job-detail/python-su...
# 2   https://www.timesjobs.com/job-detail/qa-python...
# 3   https://www.timesjobs.com/job-detail/python-de...
# 4   https://www.timesjobs.com/job-detail/python-de...
# 5   https://www.timesjobs.com/job-detail/python-de...
# 6   https://www.timesjobs.com/job-detail/python-en...
# 7   https://www.timesjobs.com/job-detail/python-tr...
# 8   https://www.timesjobs.com/job-detail/python-de...
# 9   https://www.timesjobs.com/job-detail/python-en...
# 10  https://www.timesjobs.com/job-detail/python-de...
# 11  https://www.timesjobs.com/job-detail/python-en...
# 12  https://www.timesjobs.com/job-detail/python-de...
# 13  https://www.timesjobs.com/job-detail/python-de...
# 14  https://www.timesjobs.com/job-detail/python-de...
# 15  https://www.timesjobs.com/job-detail/python-de...
# 16  https://www.timesjobs.com/job-detail/python-de...
# 17  https://www.timesjobs.com/job-detail/python-de...
# 18  https://www.timesjobs.com/job-detail/python-de...
# 19  https://www.timesjobs.com/job-detail/python-de...
# 20  https://www.timesjobs.com/job-detail/python-de...
# 21  https://www.timesjobs.com/job-detail/python-de...
# 22  https://www.timesjobs.com/job-detail/python-de...
# 23  https://www.timesjobs.com/job-detail/consultan...
# 24  https://www.timesjobs.com/job-detail/python-de...
