# %%
#importing libraries

import pandas as pd
import datetime
from datetime import date, timedelta
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import warnings
warnings.filterwarnings("ignore")

#creating connections

scope= ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
credentials= ServiceAccountCredentials.from_json_keyfile_name('client_secret.json', scope) 
client= gspread.authorize(credentials)

Recoverysheetnew='1j9hmPHNmfjJp7nn4p8EVq8aciL8NfiO3hYWdf28aDzQ'
sheet= client.open_by_key(Recoverysheetnew)
ws= sheet.worksheet('Recovery Tabs')
data = ws.get_all_values()
headers=data.pop(0)
recovery_tabs = pd.DataFrame(data,columns=headers)
tabs=list(recovery_tabs['Recovery Tabs'])
dfs=pd.DataFrame()
for i in tabs:
    if i in tabs:
        sheet= client.open_by_key(Recoverysheetnew)
        ws= sheet.worksheet(i)
        data = ws.get_all_values()
        df = pd.DataFrame(data)
        dfs = dfs.append(df,ignore_index = True)
        print(i)
    else:
        print("tab no found")
master_df=dfs.rename(columns=dfs.iloc[0]).drop(dfs.index[0]).reset_index(drop=True)
today = datetime.date.today()
previous_monday = today - datetime.timedelta(days=today.weekday())
master_df['Week Begin date'] = pd.to_datetime(master_df['Week Begin date'], errors='coerce',format='%d/%m/%Y')
df_1week = master_df[(master_df['Week Begin date'] >= pd.to_datetime(previous_monday)) & (master_df['Week Begin date'] <= pd.to_datetime(today))]
df_1week['Week Begin date']=df_1week['Week Begin date'].astype(str)
df_1week = df_1week.dropna(axis=1)
sheet= client.open_by_key(Recoverysheetnew)
ws= sheet.worksheet('Masterview')
ws.batch_clear(['A:N'])
ws.update([df_1week.columns.values.tolist()] + df_1week.values.tolist(),value_input_option='USER_ENTERED')
print("masterview updated succesfully")
# Out:
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28292/865842607.py in <module>
#      16
#      17 Recoverysheetnew='1j9hmPHNmfjJp7nn4p8EVq8aciL8NfiO3hYWdf28aDzQ'
# ---> 18 sheet= client.open_by_key(Recoverysheetnew)
#      19 ws= sheet.worksheet('Recovery Tabs')
#      20 data = ws.get_all_values()
#
# ~\anaconda3\lib\site-packages\gspread\client.py in open_by_key(self, key)
#     146         >>> gc.open_by_key('0BmgG6nO_6dprdS1MN3d3MkdPa142WFRrdnRRUWl1UFE')
#     147         """
# --> 148         return Spreadsheet(self, {"id": key})
#     149
#     150     def open_by_url(self, url):
#
# ~\anaconda3\lib\site-packages\gspread\spreadsheet.py in __init__(self, client, properties)
#      31         self._properties = properties
#      32
# ---> 33         metadata = self.fetch_sheet_metadata()
# ...

# %%
#importing libraries

import pandas as pd
import datetime
from datetime import date, timedelta
import gspread
import pygsheets
from oauth2client.service_account import ServiceAccountCredentials
import warnings
import numpy as np
warnings.filterwarnings("ignore")

#creating connections

#scope= ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
#credentials= ServiceAccountCredentials.from_json_keyfile_name('client_secret.json', scope) 
#client= gspread.authorize(credentials)

clients = pygsheets.authorize(service_file='car-master-sheet.json')

Recoverysheetnew='1j9hmPHNmfjJp7nn4p8EVq8aciL8NfiO3hYWdf28aDzQ'
sheet= clients.open_by_key(Recoverysheetnew)
ws= sheet.worksheet_by_title('Recovery Tabs')
data = ws.get_all_values()
headers=data.pop(0)
recovery_tabs = pd.DataFrame(data,columns=headers)
tabs=list(recovery_tabs['Recovery Tabs'].replace('',np.nan).dropna())
tabs
# dropna=recovery_tabs.str.replace('','NaN')
# r=dropna.dropna('NaN')
# r
# tabs=list(recovery_tabs['Recovery Tabs'])
# tabs
dfs=pd.DataFrame()
for i in tabs:
    if i in tabs:
        sheet= clients.open_by_key(Recoverysheetnew)
        ws= sheet.worksheet_by_title(i)
        data = ws.get_all_values()
        df = pd.DataFrame(data)
        dfs = dfs.append(df,ignore_index = True)
        print(i)
    else:
        print("tab no found")
master_df=dfs.rename(columns=dfs.iloc[0]).drop(dfs.index[0]).reset_index(drop=True)
today = datetime.date.today()
previous_monday = today - datetime.timedelta(days=today.weekday())
master_df['Week Begin date'] = pd.to_datetime(master_df['Week Begin date'], errors='coerce',format='%d/%m/%Y')
df_1week = master_df[(master_df['Week Begin date'] >= pd.to_datetime(previous_monday)) & (master_df['Week Begin date'] <= pd.to_datetime(today))]
df_1week['Week Begin date']=df_1week['Week Begin date'].astype(str)
df_1week = df_1week.dropna(axis=1)
df_1week=df_1week[['Week Begin date','Date of Updating','Date  of Payment','Collection of Purpose','Mode Of Payment','Cash/Online','Name of Employee','Employee ID','Amount','Mobile','DM Name', 'transferred to Name of Person', 'Bank_Transaction_ID','Order_ID']]
df_1week
sheet= clients.open_by_key(Recoverysheetnew)
ws= sheet.worksheet_by_title('Masterview')
#ws.batch_clear(['A:N'])
ws.clear(start='A',end='N')
#ws.update([df_1week.columns.values.tolist()] + df_1week.values.tolist(),value_input_option='USER_ENTERED')
ws.set_dataframe(df_1week,(1,1))
print("masterview updated succesfully")
# Out:
# Pratik
# Sagar
# Makarand
# Shubham
# Rohan
# Sachin
# RazorPay
# Paytm
# BankTransferred
# Akash Sonavane
# Mithun
# Pankesh
#       Week Begin date Date of Updating Date  of Payment  \
# 19909      2022-07-25       25/07/2022       25/07/2022
# 19910      2022-07-25       25/07/2022       25/07/2022
# 19912      2022-07-25       25/07/2022       25/07/2022
# 19914      2022-07-25       25/07/2022       25/07/2022
# 19915      2022-07-25       25/07/2022       25/07/2022
# 19917      2022-07-25       25/07/2022       25/07/2022
# 19919      2022-07-25       25/07/2022       25/07/2022
# 23261      2022-07-25       25/07/2022       25/07/2022
#
#        Collection of Purpose Mode Of Payment Cash/Online  \
# 19909  Mumbai 60:40 Recovery           Paytm      Online
# 19910  Mumbai 60:40 Recovery           Paytm      Online
# 19912  Mumbai 60:40 Recovery           Paytm      Online
# 19914  Mumbai 60:40 Recovery           Paytm      Online
# ...

# %%
# sheet= clients.open_by_key(Recoverysheetnew)
# ws= sheet.worksheet_by_title('Masterview')
# ws.clear(start='A',end='N')
# ws.set_dataframe(df_1week,(1,1))
# print("masterview updated succesfully")
# Out:
# masterview updated succesfully

# %%
#importing libraries

import pandas as pd
import datetime
from datetime import date, timedelta
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import warnings
warnings.filterwarnings("ignore")

#creating connections

scope= ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
credentials= ServiceAccountCredentials.from_json_keyfile_name('client_secret.json', scope) 
client= gspread.authorize(credentials)

Recoverysheetnew='1j9hmPHNmfjJp7nn4p8EVq8aciL8NfiO3hYWdf28aDzQ'
sheet= client.open_by_key(Recoverysheetnew)
ws= sheet.worksheet('Recovery Tabs')
data = ws.get_all_values()
headers=data.pop(0)
recovery_tabs = pd.DataFrame(data,columns=headers)
tabs=list(recovery_tabs['Recovery Tabs'])
dfs=pd.DataFrame()
for i in tabs:
    if i in tabs:
        sheet= client.open_by_key(Recoverysheetnew)
        ws= sheet.worksheet(i)
        data = ws.get_all_values()
        df = pd.DataFrame(data)
        dfs = dfs.append(df,ignore_index = True)
    else:
        print("tab no found")
master_df=dfs.rename(columns=dfs.iloc[0]).drop(dfs.index[0]).reset_index(drop=True)
# sheet= client.open_by_key(Recoverysheetnew)
# ws= sheet.worksheet('Pratik')
# data = ws.get_all_values()
# pratik_df = pd.DataFrame(data)
# pratik_df
# sheet= client.open_by_key(Recoverysheetnew)
# ws= sheet.worksheet('Akash Sonavane')
# data = ws.get_all_values()
# akash_df= pd.DataFrame(data)
# akash_df
# sheet= client.open_by_key(Recoverysheetnew)
# ws= sheet.worksheet('Sagar')
# data = ws.get_all_values()
# sagar_df= pd.DataFrame(data)
# sagar_df
# sheet= client.open_by_key(Recoverysheetnew)
# ws= sheet.worksheet('Makarand')
# data = ws.get_all_values()
# Makarand_df= pd.DataFrame(data)
# Makarand_df
# sheet= client.open_by_key(Recoverysheetnew)
# ws= sheet.worksheet('Shubham')
# data = ws.get_all_values()
# Shubham_df= pd.DataFrame(data)
# Shubham_df
# sheet= client.open_by_key(Recoverysheetnew)
# ws= sheet.worksheet('Sachin')
# data = ws.get_all_values()
# Sachin_df= pd.DataFrame(data)
# Sachin_df
# sheet= client.open_by_key(Recoverysheetnew)
# ws= sheet.worksheet('Rohan')
# data = ws.get_all_values()
# Rohan_df= pd.DataFrame(data)
# Rohan_df
# sheet= client.open_by_key(Recoverysheetnew)
# ws= sheet.worksheet('RazorPay')
# data = ws.get_all_values()
# RazorPay_df= pd.DataFrame(data)
# RazorPay_df
# sheet= client.open_by_key(Recoverysheetnew)
# ws= sheet.worksheet('Paytm')
# data = ws.get_all_values()
# Paytm_df= pd.DataFrame(data)
# Paytm_df
# sheet= client.open_by_key(Recoverysheetnew)
# ws= sheet.worksheet('BankTransferred')
# data = ws.get_all_values()
# BankTransferred_df= pd.DataFrame(data)
# BankTransferred_df
# master_df=pd.concat([pratik_df,akash_df,sagar_df,Sachin_df,Makarand_df,Shubham_df,Rohan_df,RazorPay_df,Paytm_df,BankTransferred_df],ignore_index = True)
# master_df.rename(columns=master_df.iloc[0], inplace = True)
# master_df.drop(master_df.index[0], inplace = True)
today = datetime.date.today()
previous_monday = today - datetime.timedelta(days=today.weekday())
# master_df['Date of Updating']= master_df['Date of Updating'].str.replace('-', '/')
# master_df['Date of Updating'] = pd.to_datetime(master_df['Date of Updating'], errors='coerce',format='%d/%m/%Y')
# master_df['Date  of Payment']= master_df['Date  of Payment'].str.replace('-', '/')
# master_df['Date  of Payment'] = pd.to_datetime(master_df['Date  of Payment'], errors='coerce',format='%d/%m/%Y')
# master_df['Week Begin date']= master_df['Week Begin date'].str.replace('-', '/')
master_df['Week Begin date'] = pd.to_datetime(master_df['Week Begin date'], errors='coerce',format='%d/%m/%Y')
df_1week = master_df[(master_df['Week Begin date'] >= pd.to_datetime(previous_monday)) & (master_df['Week Begin date'] <= pd.to_datetime(today))]
df_1week['Week Begin date']=df_1week['Week Begin date'].astype(str)
# df_1week['Date of Updating']=df_1week['Date of Updating'].astype(str)
# df_1week['Date  of Payment']=df_1week['Date  of Payment'].astype(str)
df_1week = df_1week.dropna(axis=1)
df_1week
df1w=df_1week.loc[df_1week['Collection of Purpose'].isin(['Mumbai 60:40 Recovery','Mumbai leasing Rent'])]
sheet= client.open_by_key(Recoverysheetnew)
ws= sheet.worksheet('MS')
ws.batch_clear(['A:N'])
ws.update([df1w.columns.values.tolist()] + df1w.values.tolist(),value_input_option='USER_ENTERED')
print("masterview updated succesfully")
#changes to ms:- mumbai 60:40 recovery and Mumbai leasing Rent
# Out:
#      Week Begin date Date of Updating      Date  of Payment  \
# 5861      2022-06-20       20/06/2022  2022-06-19 02:07:38'
# 5899      2022-06-20       20/06/2022  2022-06-19 17:16:32'
# 5904      2022-06-20       20/06/2022  2022-06-19 19:57:24'
# 5910      2022-06-20       20/06/2022  2022-06-19 22:56:51'
# 5916      2022-06-20       20/06/2022  2022-06-20 01:31:11'
# 5917      2022-06-20       20/06/2022  2022-06-20 01:35:35'
# 5920      2022-06-20       20/06/2022  2022-06-20 07:51:38'
# 5921      2022-06-20       20/06/2022  2022-06-20 07:52:52'
# 5923      2022-06-20       20/06/2022  2022-06-20 09:06:52'
# 5924      2022-06-20       20/06/2022  2022-06-20 09:10:19'
# 5925      2022-06-20       20/06/2022  2022-06-20 10:53:14'
# 5926      2022-06-20       20/06/2022  2022-06-20 10:54:00'
#
#       Collection of Purpose Mode Of Payment Cash/Online  \
# 5861  Mumbai 60:40 Recovery           Paytm      Online
# 5899    Mumbai leasing Rent           Paytm      Online
# ...

# %%
df_1week.count()
# Out:
# Week Begin date                  53
# Date of Updating                 53
# Date  of Payment                 53
# Collection of Purpose            53
# Mode Of Payment                  53
# Cash/Online                      53
# Name of Employee                 53
# Employee ID                      53
# Amount                           53
# Mobile                           53
# DM Name                          53
# transferred to Name of Person    53
# Bank_Transaction_ID              53
# Order_ID                         53
# dtype: int64

# %%
df_1week.dtypes
# Out:
# Week Begin date                  object
# Date of Updating                 object
# Date  of Payment                 object
# Collection of Purpose            object
# Mode Of Payment                  object
# Cash/Online                      object
# Name of Employee                 object
# Employee ID                      object
# Amount                           object
# Mobile                           object
# DM Name                          object
# transferred to Name of Person    object
# Bank_Transaction_ID              object
# Order_ID                         object
# NaN                              object
# dtype: object

# %%
#importing libraries

import pandas as pd
import datetime
from datetime import date, timedelta
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import warnings
warnings.filterwarnings("ignore")

#creating connections

scope= ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
credentials= ServiceAccountCredentials.from_json_keyfile_name('client_secret.json', scope) 
client= gspread.authorize(credentials)

Recoverysheetnew='1j9hmPHNmfjJp7nn4p8EVq8aciL8NfiO3hYWdf28aDzQ'
sheet= client.open_by_key(Recoverysheetnew)
ws= sheet.worksheet('Recovery Tabs')
data = ws.get_all_values()
headers=data.pop(0)
recovery_tabs = pd.DataFrame(data,columns=headers)
tabs=list(recovery_tabs['Recovery Tabs'])
dfs=pd.DataFrame()
for i in tabs:
    if i in tabs:
        sheet= client.open_by_key(Recoverysheetnew)
        ws= sheet.worksheet(i)
        data = ws.get_all_values()
        df = pd.DataFrame(data)
        dfs = dfs.append(df,ignore_index = True)
    else:
        print("tab no found")
master_df=dfs.rename(columns=dfs.iloc[0]).drop(dfs.index[0]).reset_index(drop=True)
today = datetime.date.today()
previous_monday = today - datetime.timedelta(days=today.weekday())
master_df['Week Begin date'] = pd.to_datetime(master_df['Week Begin date'], errors='coerce',format='%d/%m/%Y')
df_1week = master_df[(master_df['Week Begin date'] >= pd.to_datetime(previous_monday)) & (master_df['Week Begin date'] <= pd.to_datetime(today))]
df_1week['Week Begin date']=df_1week['Week Begin date'].astype(str)
df_1week = df_1week.dropna(axis=1)
df1w=df_1week.loc[df_1week['Collection of Purpose'].isin(['Mumbai 60:40 Recovery','Mumbai leasing Rent'])]
sheet= client.open_by_key(Recoverysheetnew)
ws= sheet.worksheet('MS')
ws.batch_clear(['A:N'])
ws.update([df1w.columns.values.tolist()] + df1w.values.tolist(),value_input_option='USER_ENTERED')
print("masterview updated succesfully")
# Out:
#      Week Begin date Date of Updating      Date  of Payment  \
# 165       2022-06-20       20/06/2022            20/06/2022
# 166       2022-06-20       20/06/2022            20/06/2022
# 167       2022-06-20       20/06/2022            20/06/2022
# 179       2022-06-20       20-06-2022            20-06-2022
# 180       2022-06-20       20-06-2022            20-06-2022
# 181       2022-06-20       20-06-2022            20-06-2022
# 182       2022-06-20       20-06-2022            20-06-2022
# 325       2022-06-20       20/06/2022            20/06/2022
# 326       2022-06-20       20/06/2022            20/06/2022
# 4121      2022-06-20       20/06/2022  2022-06-07 17:34:36'
# 5867      2022-06-20       20/06/2022  2022-06-19 02:07:38'
# 5905      2022-06-20       20/06/2022  2022-06-19 17:16:32'
# 5910      2022-06-20       20/06/2022  2022-06-19 19:57:24'
# 5916      2022-06-20       20/06/2022  2022-06-19 22:56:51'
# 5921      2022-06-20       20/06/2022  2022-06-20 01:27:39'
# ...

# %%
today = datetime.date.today()
print(today)
previous_monday_week= today - datetime.timedelta(days=8)
print(previous_monday_week)
previous_monday = today - datetime.timedelta(days=today.weekday())
print(previous_monday)
# Out:
# 2022-06-14
# 2022-06-06
# 2022-06-13

# %%
master_df.columns
# Out:
# Index([              'Week Begin date',              'Date of Updating',
#                     'Date  of Payment',         'Collection of Purpose',
#                      'Mode Of Payment',                   'Cash/Online',
#                     'Name of Employee',                   'Employee ID',
#                               'Amount',                        'Mobile',
#                              'DM Name', 'transferred to Name of Person',
#                  'Bank_Transaction_ID',                      'Order_ID',
#                                    nan],
#       dtype='object')

# %%
master_df = master_df[pd.notnull(master_df.iloc['Date of Payment'])]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8844/138935925.py in <module>
# ----> 1 master_df = master_df[pd.notnull(master_df.iloc['Date of Payment'])]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     965
#     966             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967             return self._getitem_axis(maybe_callable, axis=axis)
#     968
#     969     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1515             key = item_from_zerodim(key)
#    1516             if not is_integer(key):
# -> 1517                 raise TypeError("Cannot index by location index with a non-integer key")
#    1518
#    1519             # validate the location
#
# ...

# %%
sheet= client.open_by_key(Recoverysheetnew)
ws= sheet.worksheet('Paytm')
data = ws.get_all_values()
Paytm_df= pd.DataFrame(data)
Paytm_df
# Out:
#                     0                 1                 2   \
# 0      Week Begin date  Date of Updating  Date  of Payment
# 1                                                        0
# 2                                                        0
# 3                                                        0
# 4                                                        0
# ...                ...               ...               ...
# 13053
# 13054
# 13055
# 13056
# 13057
#
#                           3                4            5                 6   \
# 0      Collection of Purpose  Mode Of Payment  Cash/Online  Name of Employee
# 1                                       Paytm       Online
# 2                                       Paytm       Online
# 3                                       Paytm       Online
# 4                                       Paytm       Online
# ...                      ...              ...          ...               ...
# ...

# %%
master_df = master_df[master_df['Employee ID'].str.startswith('ETM')]
master_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8844/2426846269.py in <module>
# ----> 1 master_df = master_df[master_df['Employee ID'].str.startswith('ETM')]
#       2 master_df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     387                     raise KeyError(key) from err
#     388             self._check_indexing_error(key)
# --> 389             raise KeyError(key)
# ...

# %%
master_df = master_df[pd.notnull(master_df['Employee ID'])]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8844/792022078.py in <module>
# ----> 1 master_df = master_df[pd.notnull(master_df['Employee ID'])]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3490         # Do we have a (boolean) DataFrame?
#    3491         if isinstance(key, DataFrame):
# -> 3492             return self.where(key)
#    3493
#    3494         # Do we have a (boolean) 1d indexer?
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in where(self, cond, other, inplace, axis, level, errors, try_cast)
# ...

# %%
master_df.rename(columns=master_df.iloc[0], inplace = True)
master_df = master_df[master_df['Employee ID'].str.startswith('ETM')]
master_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8844/1254372414.py in <module>
#       1 master_df.rename(columns=master_df.iloc[0], inplace = True)
# ----> 2 master_df = master_df[master_df['Employee ID'].str.startswith('ETM')]
#       3 master_df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3469             # is_iterator to exclude generator e.g. test_getitem_listlike
#    3470             # shortcut if the key is in columns
# -> 3471             if self.columns.is_unique and key in self.columns:
#    3472                 if isinstance(self.columns, MultiIndex):
#    3473                     return self._getitem_multilevel(key)
#
# ~\anaconda3\lib\site-packages\pandas\_libs\properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# ...

# %%
# !pip3 install --upgrade pandas
# Out:
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.4
#     Uninstalling pandas-1.3.4:
#       Successfully uninstalled pandas-1.3.4
# ...
# WARNING: Ignoring invalid distribution -ysql-connector-python (c:\users\sagar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ysql-connector-python (c:\users\sagar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ysql-connector-python (c:\users\sagar\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -ysql-connector-python (c:\users\sagar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ysql-connector-python (c:\users\sagar\anaconda3\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# ,Sachin_df,Makarand_df,Shubham_df,Rohan_df,RazorPay_df,Paytm_df,BankTransferred_df
# Out:
#                 0                 1                 2                      3   \
# 0  Week Begin date  Date of Updating  Date  of Payment  Collection of Purpose
#
#                 4            5                 6            7       8   \
# 0  Mode Of Payment  Cash/Online  Name of Employee  Employee ID  Amount
#
#        9        10                             11                   12  \
# 0  Mobile  DM Name  transferred to Name of Person  Bank_Transaction_ID
#
#          13
# 0  Order_ID

# %%
akash_df
# Out:
#                 0                 1                 2                      3   \
# 0  Week Begin date  Date of Updating  Date  of Payment  Collection of Purpose
#
#                 4            5                 6            7       8   \
# 0  Mode Of Payment  Cash/Online  Name of Employee  Employee ID  Amount
#
#        9        10                             11                   12  \
# 0  Mobile  DM Name  transferred to Name of Person  Bank_Transaction_ID
#
#          13
# 0  Order_ID

# %%
sagar_df
# Out:
#                  0                 1                 2   \
# 0   Week Begin date  Date of Updating  Date  of Payment
# 1        13/06/2022        13/06/2022
# 2        13/06/2022        13/06/2022
# 3        13/06/2022        13/06/2022
# 4        13/06/2022        13/06/2022
# 5        13/06/2022        13/06/2022
# 6        13/06/2022        13/06/2022
# 7        13/06/2022        13/06/2022
# 8        13/06/2022        13/06/2022
# 9        13/06/2022        13/06/2022
# 10       13/06/2022        13/06/2022
# 11       13/06/2022        13/06/2022
#
#                          3                4            5   \
# 0     Collection of Purpose  Mode Of Payment  Cash/Online
# 1     Mumbai 60:40 Recovery             Cash         Cash
# 2     Mumbai 60:40 Recovery             Cash         Cash
# 3   Mumbai leasing Recovery             Cash         Cash
# 4     Mumbai 60:40 Recovery             Cash         Cash
# 5    Mumbai Leasing Deposit             Cash         Cash
# ...

# %%
Makarand_df
# Out:
#                  0                 1                 2   \
# 0   Week Begin date  Date of Updating  Date  of Payment
# 1        13/06/2022        13/06/2022        13/06/2022
# 2        13/06/2022        13/06/2022        13/06/2022
# 3        13/06/2022        13/06/2022        13/06/2022
# 4        13/06/2022        13/06/2022        13/06/2022
# 5        13/06/2022        13/06/2022        13/06/2022
# 6        13/06/2022        13/06/2022        13/06/2022
# 7        13/06/2022        13/06/2022        13/06/2022
# 8        13/06/2022        13/06/2022        13/06/2022
# 9        13/06/2022        13/06/2022        13/06/2022
# 10       13/06/2022        13/06/2022        13/06/2022
# 11       13/06/2022        13/06/2022        13/06/2022
# 12       13/06/2022        13/06/2022        13/06/2022
# 13       13/06/2022        13/06/2022        13/06/2022
# 14       13/06/2022        13/06/2022        13/06/2022
#
#                          3                4            5   \
# ...

# %%
#importing libraries

import pandas as pd
import datetime
from datetime import date, timedelta
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import warnings
warnings.filterwarnings("ignore")

#creating connections

scope= ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
credentials= ServiceAccountCredentials.from_json_keyfile_name('client_secret.json', scope) 
client= gspread.authorize(credentials)
Recoverysheetnew='1j9hmPHNmfjJp7nn4p8EVq8aciL8NfiO3hYWdf28aDzQ'
sheet= client.open_by_key(Recoverysheetnew)
ws= sheet.worksheet('Pratik')
data_pratik = ws.get_all_values()
data_pratik
pratik_df = pd.DataFrame(data_pratik)
pratik_df
sheet= client.open_by_key(Recoverysheetnew)
ws= sheet.worksheet('Akash Sonavane')
data_akash = ws.get_all_values()
akash_df = pd.DataFrame(data_akash)
akash_df
# akash_df.merge(pratik_df, how='inner', on='Week Begin date')
# akash_df
# df = pratik_df.append([akash_df],ignore_index=True)
# df
df =pd.concat([pratik_df,akash_df],axis=1,ignore_index = True)
df
# Out:
#                  0                 1                 2   \
# 0   Week Begin date  Date of Updating  Date  of Payment
# 1        13/06/2022        13/06/2022        13/06/2022
# 2        13/06/2022        13/06/2022        13/06/2022
# 3        13/06/2022        13/06/2022        13/06/2022
# 4        13/06/2022        13/06/2022        13/06/2022
# 5        13/06/2022        13/06/2022        13/06/2022
# 6        13/06/2022        13/06/2022        13/06/2022
# 7        13/06/2022        13/06/2022        13/06/2022
# 8        13/06/2022        13/06/2022        13/06/2022
# 9        13/06/2022        13/06/2022        13/06/2022
# 10       13/06/2022        13/06/2022        13/06/2022
# 11       13/06/2022        13/06/2022        13/06/2022
# 12       13/06/2022        13/06/2022        13/06/2022
# 13       13/06/2022        13/06/2022        13/06/2022
# 14       13/06/2022        13/06/2022        13/06/2022
# 15       13/06/2022        13/06/2022        13/06/2022
# 16
# 17
# ...

# %%
sheet= client.open_by_key(Recoverysheetnew)
ws= sheet.worksheet('Akash Sonavane')
data_akash = ws.get_all_values()
headers = data.pop(0)
akash_df = pd.DataFrame(data_akash,columns = headers)
akash_df
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8292/1567225440.py in <module>
#       2 ws= sheet.worksheet('Akash Sonavane')
#       3 data_akash = ws.get_all_values()
# ----> 4 headers = data.pop(0)
#       5 akash_df = pd.DataFrame(data_akash,columns = headers)
#       6 akash_df
#
# IndexError: pop from empty list

# %%
sheet= client.open_by_key(Recoverysheetnew)
ws= sheet.worksheet('Akash Sonavane')
data = ws.get_all_values()
akash_df= pd.DataFrame(data,columns = headers)
akash_df.dtypes
# Out:
# Week Begin date                  object
# Date of Updating                 object
# Date  of Payment                 object
# Collection of Purpose            object
# Mode Of Payment                  object
# Cash/Online                      object
# Name of Employee                 object
# Employee ID                      object
# Amount                           object
# Mobile                           object
# DM Name                          object
# transferred to Name of Person    object
# Bank_Transaction_ID              object
# Order_ID                         object
# dtype: object

# %%
sheet= client.open_by_key(Recoverysheetnew)
ws= sheet.worksheet('Akash Sonavane')
data = ws.get_all_values()
headers = data.pop(0)
akash_df= pd.DataFrame(data,columns=headers)
akash_df
# Out:
# Empty DataFrame
# Columns: [Week Begin date, Date of Updating, Date  of Payment, Collection of Purpose, Mode Of Payment, Cash/Online, Name of Employee, Employee ID, Amount, Mobile, DM Name, transferred to Name of Person, Bank_Transaction_ID, Order_ID]
# Index: []
