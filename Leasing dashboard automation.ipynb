# %%
#importing Libraries

import pandas as pd
import datetime
from datetime import date, timedelta
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import warnings
warnings.filterwarnings("ignore")

#Leasing Dashboard Korum Mall 

scope= ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
credentials= ServiceAccountCredentials.from_json_keyfile_name('client_secret.json', scope) 
client= gspread.authorize(credentials)
sheet= client.open('New Leasing Master')
ws= sheet.worksheet('Allocation Responses')
data = ws.get_all_values()
sheet= client.open('Leasing Dashboard')
ws= sheet.worksheet('Live Data')
ws.update(data,value_input_option='USER_ENTERED')
print("Leasing Dashboard Korum Mall Live Data Succesfully")

#Leasing Dashboard Chunabhatti 

scope= ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
credentials= ServiceAccountCredentials.from_json_keyfile_name('client_secret.json', scope) 
client= gspread.authorize(credentials)
sheet= client.open('Leasing Master - Vinay Bhai')
ws= sheet.worksheet('Allocation Responses')
data = ws.get_all_values()
sheet= client.open('Leasing Dashboard - Vinay Bhai')
ws= sheet.worksheet('Live Data')
ws.update(data,value_input_option='USER_ENTERED')
print("Leasing Dashboard Chunabhatti Live Data Updated Succesfully")
# Out:
# Leasing Dashboard Korum Mall Live Data Succesfully
# Leasing Dashboard Chunabhatti Updated Succesfully

# %%
#importing Libraries
import pygsheets
import pandas as pd
import datetime
from datetime import date, timedelta
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import warnings
warnings.filterwarnings("ignore")

#Leasing Dashboard Korum Mall 

scope= ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
credentials= ServiceAccountCredentials.from_json_keyfile_name('client_secret.json', scope) 
client= gspread.authorize(credentials)

clients = pygsheets.authorize(service_file='client_secret.json')

sheet= client.open('New Leasing Master')
ws= sheet.worksheet('Allocation Responses')
data = ws.get_all_values()
headers=data.pop(0)
data_df=pd.DataFrame(data,columns=headers)
leasing_mumbai_data_df=data_df.loc[:,['Timestamp', 'Allocation or Car Jama ', 'Member Name',
       'Rent for first Day?', 'Date', 'Driver Ola Balance', 'Car Jama Number',
       'Car Status', 'Allocation Vehicle Number', 'Key Handover to?',
       'Penalty Amount', 'Penalty Reason', 'More details of Penalty',
       'ETM + Others', 'ETM ID', 'Driver Name', 'Reason for Other', 'Fastag',
        'Car Number', 'ETM']]  
leasing_mumbai_data_df
sheet= clients.open('Leasing Dashboard')
ws= sheet.worksheet_by_title('Live Data')
ws.set_dataframe(leasing_mumbai_data_df,(1,1))
print("Leasing Dashboard Korum Mall Live Data Succesfully")
# Out:
# Leasing Dashboard Korum Mall Live Data Succesfully

# %%
leasing_mumbai_data_df.dtypes
# Out:
# Timestamp                    object
# Allocation or Car Jama       object
# Member Name                  object
# Rent for first Day?          object
# Date                         object
# Driver Ola Balance           object
# Car Jama Number              object
# Car Status                   object
# Allocation Vehicle Number    object
# Key Handover to?             object
# Penalty Amount               object
# Penalty Reason               object
# More details of Penalty      object
# ETM + Others                 object
# ETM ID                       object
# Driver Name                  object
# Reason for Other             object
# Fastag                       object
# Car Number                   object
# ETM                          object
# dtype: object

# %%
data_df.columns
# Out:
# Index(['Timestamp', 'Allocation or Car Jama ', 'Member Name',
#        'Rent for first Day?', 'Date', 'Driver Ola Balance', 'Car Jama Number',
#        'Car Status', 'Allocation Vehicle Number', 'Key Handover to?',
#        'Penalty Amount', 'Penalty Reason', 'More details of Penalty',
#        'ETM + Others', 'ETM ID', 'Driver Name', 'Reason for Other', 'Fastag',
#        'Agreement Status', 'Driver Phone Number', 'Allocation Type',
#        'Deposit in Cash', 'Deposit Online', 'Car Number', 'ETM',
#        'Active or Inactive'],
#       dtype='object')

# %%
sheet= client.open('Leasing Master - Vinay Bhai')
ws= sheet.worksheet('Allocation Responses')
data = ws.get_all_values()
headers=data.pop(0)
data_df=pd.DataFrame(data,columns=headers)
data_df
# Out:
#              टाइमस्टैम्प Allocation or Car Jama  Member Name  \
# 0    18/04/2022 12:15:40                Car Jama  Vinay Bhai
# 1    18/04/2022 17:00:48                Car Jama  Vinay Bhai
# 2    18/04/2022 18:21:13                Car Jama  Vinay Bhai
# 3    18/04/2022 18:22:28              Allocation  Vinay Bhai
# 4    19/04/2022 12:18:00              Allocation  Vinay Bhai
# ..                   ...                     ...         ...
# 663  08/08/2022 11:37:55                Car Jama  Vinay Bhai
# 664  08/08/2022 11:39:52              Allocation  Vinay Bhai
# 665  08/08/2022 12:41:23                Car Jama  Vinay Bhai
# 666  08/08/2022 13:10:37                Car Jama  Vinay Bhai
# 667  08/08/2022 13:15:28                Car Jama  Vinay Bhai
#
#     Rent for first Day?        Date Driver Ola Balance Car Jama Number  \
# 0                  None  18/04/2022                  0      MH01DR2960
# 1                  None  18/04/2022                  0      MH01CV7096
# 2                  Half  18/04/2022                  0      MH01CV4383
# 3                  None  18/04/2022                  0
# 4                  None  18/04/2022                  0
# ..                  ...         ...                ...             ...
# 663                Full  06/08/2022                  0      MH03CV5395
# 664                None  06/08/2022                  0
# 665                None  05/08/2022                565      MH01CV7096
# 666                None  08/08/2022                  0      MH01CV7534
# 667                None  08/08/2022                  0      MH01CV6886
#
#          Car Status Allocation Vehicle Number Key Handover to? Penalty Amount  \
# 0    Ready to Allot                                                         0
# 1    Ready to Allot                                                         0
# 2    Ready to Allot                                                         0
# 3                                  MH01DR2960
# 4                                  MH01CV4383
# ..              ...                       ...              ...            ...
# 663  Ready to Allot                                                         0
# 664                                MH03CV5395
# 665       Repairing                                    Garage               0
# 666  Ready to Allot                                                         0
# 667  Ready to Allot                                                         0
#
#     Penalty Reason More details of Penalty ETM + Others    ETM ID  \
# 0                                                        ETM05852
# 1                                                        ETM18158
# 2                                                        ETM19583
# 3                                                   ETM  ETM19573
# 4                                                   ETM  ETM19374
# ..             ...                     ...          ...       ...
# 663                                                      ETM16318
# 664                                                 ETM  ETM20976
# 665                                                      ETM11433
# 666                                                      ETM07109
# 667                                                      ETM12309
#
#                 Driver Name Reason for Other Fastag  Car number       ETM
# 0                9004385290                      60  MH01DR2960  ETM05852
# 1               Sunil Yadav                      60  MH01CV7096  ETM18158
# 2             Salman shaikh                      60  MH01CV4383  ETM19583
# 3             Salman Shaikh                      60  MH01DR2960  ETM19573
# 4               Suhail Sura                      60  MH01CV4383  ETM19374
# ..                      ...              ...    ...         ...       ...
# 663         Aniket Savekar                      -13  MH03CV5395  ETM16318
# 664      Santosh Rangavkar                      -13  MH03CV5395  ETM20976
# 665  Mohd Junaid Choudhary                      -91  MH01CV7096  ETM11433
# 666            Sufiyan Khan                      60  MH01CV7534  ETM07109
# 667              Raj Bhadur                      76  MH01CV6886  ETM12309
#
# [668 rows x 20 columns]
